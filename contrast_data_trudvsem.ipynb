# %%
"""
Скрипт для сравнения двух файлов свода данных 
"""
# Out:
# '\nСкрипт для сравнения двух файлов свода данных \n'

# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
def sum_category(row:pd.Series,user_sep:str):
    """
    Суммирование колонок для ID
    """
    out_id = f'{user_sep}'.join(row.tolist()) # создаем выходную строку

    return out_id

# %%
first_file = 'data/Аналитика по вакансиям региона/15_03_2024/Свод по региону Бурятия от 14 марта.xlsx'
second_file = 'data/Аналитика по вакансиям региона/16_03_2024/Свод по региону Бурятия от 16 марта.xlsx'

# %%
# Список обязательных колонок 
lst_svod_sheets = ['Вакансии по отраслям','Вакансии по работодателям','Зарплата по отраслям','Зарплата по работодателям',
                   'Образование по отраслям','Образование по работодателям','График работы по отраслям','График работы по работодателям',
                   'Тип занятости по отраслям','Тип занятости по работодателям','Квоты по отраслям','Квоты по работодателям',
                   'Требуемый опыт по отраслям','Требуемый опыт по работодателям']

# %%
first_df = pd.read_excel(first_file,sheet_name='Образование по отраслям') # первый файл для сравнения
second_df = pd.read_excel(second_file,sheet_name='Образование по отраслям') # второй файл для сравнения

# %%
lst_not_standard_sheets = ['Зарплата по отраслям','Зарплата по работодателям'] # список листов без колонки Количество вакансий

# %%
first_df.head()
# Out:
#                                   Сфера деятельности  \
# 0          Административная работа, секретариат, АХО
# 1          Административная работа, секретариат, АХО
# 2          Административная работа, секретариат, АХО
# 3  Банки, кредит, страхование, пенсионное обеспеч...
# 4  Банки, кредит, страхование, пенсионное обеспеч...
#
#                 Образование  Количество вакансий
# 0                    Высшее                   49
# 1                   Среднее                   10
# 2  Среднее профессиональное                   20
# 3                    Высшее                   11
# 4                Не указано                   16

# %%
second_df.head()
# Out:
#                                   Сфера деятельности  \
# 0          Административная работа, секретариат, АХО
# 1          Административная работа, секретариат, АХО
# 2          Административная работа, секретариат, АХО
# 3          Административная работа, секретариат, АХО
# 4  Банки, кредит, страхование, пенсионное обеспеч...
#
#                 Образование  Количество вакансий
# 0                    Высшее                   90
# 1                Не указано                   71
# 2                   Среднее                   10
# 3  Среднее профессиональное                    5
# 4                    Высшее                   11

# %%
first_key_columns = list(first_df.columns)
first_key_columns.remove('Количество вакансий')

second_key_columns = list(second_df.columns)
second_key_columns.remove('Количество вакансий')

# %%
first_key_columns
# Out:
# ['Сфера деятельности', 'Образование']

# %%
# Делаем колонки на основе котороых будут создаваться ID строковыми
first_df[first_key_columns] = first_df[first_key_columns].astype(str)
second_df[second_key_columns] = second_df[second_key_columns].astype(str)

# %%
# Создаем колонки по которой будет вестись объединение
first_df['ID'] = first_df[first_key_columns].apply(lambda x:sum_category(x,'-'),axis=1)
second_df['ID'] = second_df[second_key_columns].apply(lambda x:sum_category(x,'-'),axis=1)

# %%
first_df
# Out:
#                                     Сфера деятельности  \
# 0            Административная работа, секретариат, АХО
# 1            Административная работа, секретариат, АХО
# 2            Административная работа, секретариат, АХО
# 3    Банки, кредит, страхование, пенсионное обеспеч...
# 4    Банки, кредит, страхование, пенсионное обеспеч...
# ..                                                 ...
# 144                                      Юриспруденция
# 145                                      Юриспруденция
# 146                                      Юриспруденция
# 147                                      Юриспруденция
# 148                                      Юриспруденция
#
#                   Образование  Количество вакансий  \
# 0                      Высшее                   49
# 1                     Среднее                   10
# 2    Среднее профессиональное                   20
# 3                      Высшее                   11
# 4                  Не указано                   16
# ..                        ...                  ...
# 144                    Высшее                   53
# 145                Не указано                   36
# 146            Основное общее                    1
# 147                   Среднее                   70
# 148  Среднее профессиональное                   43
#
#                                                     ID
# 0     Административная работа, секретариат, АХО-Высшее
# 1    Административная работа, секретариат, АХО-Среднее
# 2    Административная работа, секретариат, АХО-Сред...
# 3    Банки, кредит, страхование, пенсионное обеспеч...
# 4    Банки, кредит, страхование, пенсионное обеспеч...
# ..                                                 ...
# 144                               Юриспруденция-Высшее
# 145                           Юриспруденция-Не указано
# 146                       Юриспруденция-Основное общее
# 147                              Юриспруденция-Среднее
# 148             Юриспруденция-Среднее профессиональное
#
# [149 rows x 4 columns]

# %%
second_df.head()
# Out:
#                                   Сфера деятельности  \
# 0          Административная работа, секретариат, АХО
# 1          Административная работа, секретариат, АХО
# 2          Административная работа, секретариат, АХО
# 3          Административная работа, секретариат, АХО
# 4  Банки, кредит, страхование, пенсионное обеспеч...
#
#                 Образование  Количество вакансий  \
# 0                    Высшее                   90
# 1                Не указано                   71
# 2                   Среднее                   10
# 3  Среднее профессиональное                    5
# 4                    Высшее                   11
#
#                                                   ID
# 0   Административная работа, секретариат, АХО-Высшее
# 1  Административная работа, секретариат, АХО-Не у...
# 2  Административная работа, секретариат, АХО-Среднее
# 3  Административная работа, секретариат, АХО-Сред...
# 4  Банки, кредит, страхование, пенсионное обеспеч...

# %%
merge_df = first_df.merge(second_df,how='outer',left_on=['ID'],right_on=['ID'],indicator=True)

# %%
# удаляем лишние колонки
del_columns = [column for column in merge_df.columns if ('вакансий' not in column) & ('ID' not in column)]

# %%
merge_df.drop(columns=del_columns,inplace=True)

# %%
merge_df=merge_df.reindex(columns=['ID','Количество вакансий_x','Количество вакансий_y']) # меняем местами
merge_df.columns = ['Показатель','Первая таблица','Вторая таблица']

# %%
merge_df.fillna(0,inplace=True)

# %%
merge_df[['Первая таблица','Вторая таблица']] = merge_df[['Первая таблица','Вторая таблица']].astype(float,errors='ignore')

# %%
merge_df['Разница'] = merge_df['Вторая таблица'] - merge_df['Первая таблица']
merge_df['Абсолютная разница'] = abs(merge_df['Вторая таблица'] - merge_df['Первая таблица'])
merge_df['Изменение в %'] = round(((merge_df['Вторая таблица'] - merge_df['Первая таблица']) / merge_df['Первая таблица']) * 100,2)

# %%
merge_df['Отношение второй таблицы к первой %'] = round((merge_df['Вторая таблица']/ merge_df['Первая таблица'])*100,2)

# %%
merge_df
# Out:
#                                             Показатель  Первая таблица  \
# 0     Административная работа, секретариат, АХО-Высшее            49.0
# 1    Административная работа, секретариат, АХО-Среднее            10.0
# 2    Административная работа, секретариат, АХО-Сред...            20.0
# 3    Банки, кредит, страхование, пенсионное обеспеч...            11.0
# 4    Банки, кредит, страхование, пенсионное обеспеч...            16.0
# ..                                                 ...             ...
# 145                           Юриспруденция-Не указано            36.0
# 146                       Юриспруденция-Основное общее             1.0
# 147                              Юриспруденция-Среднее            70.0
# 148             Юриспруденция-Среднее профессиональное            43.0
# 149  Административная работа, секретариат, АХО-Не у...             0.0
#
#      Вторая таблица  Разница  Абсолютная разница  Изменение в %  \
# 0              90.0     41.0                41.0          83.67
# 1              10.0      0.0                 0.0           0.00
# 2               5.0    -15.0                15.0         -75.00
# 3              11.0      0.0                 0.0           0.00
# 4              16.0      0.0                 0.0           0.00
# ..              ...      ...                 ...            ...
# 145            36.0      0.0                 0.0           0.00
# 146             1.0      0.0                 0.0           0.00
# 147            70.0      0.0                 0.0           0.00
# 148            43.0      0.0                 0.0           0.00
# 149            71.0     71.0                71.0            inf
#
#      Отношение второй таблицы к первой %
# 0                                 183.67
# 1                                 100.00
# 2                                  25.00
# 3                                 100.00
# 4                                 100.00
# ..                                   ...
# 145                               100.00
# 146                               100.00
# 147                               100.00
# 148                               100.00
# 149                                  inf
#
# [150 rows x 7 columns]

# %%
merge_df.sort_values(by='Показатель',inplace=True)# Сортируем по показателю

# %%
merge_df
# Out:
#                                             Показатель  Первая таблица  \
# 0     Административная работа, секретариат, АХО-Высшее            49.0
# 149  Административная работа, секретариат, АХО-Не у...             0.0
# 1    Административная работа, секретариат, АХО-Среднее            10.0
# 2    Административная работа, секретариат, АХО-Сред...            20.0
# 3    Банки, кредит, страхование, пенсионное обеспеч...            11.0
# ..                                                 ...             ...
# 144                               Юриспруденция-Высшее            53.0
# 145                           Юриспруденция-Не указано            36.0
# 146                       Юриспруденция-Основное общее             1.0
# 147                              Юриспруденция-Среднее            70.0
# 148             Юриспруденция-Среднее профессиональное            43.0
#
#      Вторая таблица  Разница  Абсолютная разница  Изменение в %  \
# 0              90.0     41.0                41.0          83.67
# 149            71.0     71.0                71.0            inf
# 1              10.0      0.0                 0.0           0.00
# 2               5.0    -15.0                15.0         -75.00
# 3              11.0      0.0                 0.0           0.00
# ..              ...      ...                 ...            ...
# 144            53.0      0.0                 0.0           0.00
# 145            36.0      0.0                 0.0           0.00
# 146             1.0      0.0                 0.0           0.00
# 147            70.0      0.0                 0.0           0.00
# 148            43.0      0.0                 0.0           0.00
#
#      Отношение второй таблицы к первой %
# 0                                 183.67
# 149                                  inf
# 1                                 100.00
# 2                                  25.00
# 3                                 100.00
# ..                                   ...
# 144                               100.00
# 145                               100.00
# 146                               100.00
# 147                               100.00
# 148                               100.00
#
# [150 rows x 7 columns]

# %%
merge_df.to_excel('data/dfgdgf.xlsx',index=False)
