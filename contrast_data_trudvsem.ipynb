# %%
"""
Скрипт для сравнения двух файлов свода данных 
"""
# Out:
# '\nСкрипт для сравнения двух файлов свода данных \n'

# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
first_file = 'data/Аналитика по вакансиям региона/15_03_2024/Свод по региону Бурятия от 14 марта.xlsx'
second_file = 'data/Аналитика по вакансиям региона/16_03_2024/Свод по региону Бурятия от 16 марта.xlsx'

# %%
first_df = pd.read_excel(first_file) # первый файл для сравнения
second_df = pd.read_excel(second_file) # второй файл для сравнения

# %%
# Список обязательных колонок 
lst_svod_sheets = ['Вакансии по отраслям','Вакансии по работодателям','Зарплата по отраслям','Зарплата по работодателям',
                   'Образование по отраслям','Образование по работодателям','График работы по отраслям','График работы по работодателям',
                   'Тип занятости по отраслям','Тип занятости по работодателям','Квоты по отраслям','Квоты по работодателям',
                   'Требуемый опыт по отраслям','Требуемый опыт по работодателям']

# %%
lst_not_standard_sheets = ['Зарплата по отраслям','Зарплата по работодателям'] # список листов без колонки Количество вакансий

# %%
first_df.head()
# Out:
#                                   Сфера деятельности  Количество вакансий
# 0                                       Производство                 1724
# 1  Строительство, ремонт, стройматериалы, недвижи...                 1589
# 2           Здравоохранение и социальное обеспечение                 1491
# 3              Продажи, закупки, снабжение, торговля                  734
# 4                                 Образование, наука                  732

# %%
second_df.head()
# Out:
#                                   Сфера деятельности  Количество вакансий
# 0                                       Производство                 1800
# 1           Здравоохранение и социальное обеспечение                 1491
# 2              Продажи, закупки, снабжение, торговля                  734
# 3                                 Образование, наука                  732
# 4  Государственная служба, некоммерческие организ...                  715

# %%
first_key_columns = list(first_df.columns)
first_key_columns.remove('Количество вакансий')

second_key_columns = list(second_df.columns)
second_key_columns.remove('Количество вакансий')

# %%
first_key_columns
# Out:
# ['Сфера деятельности']

# %%
# Делаем колонки на основе котороых будут создаваться ID строковыми
first_df[first_key_columns] = first_df[first_key_columns].astype(str)
second_df[second_key_columns] = second_df[second_key_columns].astype(str)

# %%
# Создаем колонки по которой будет вестись объединение
first_df['ID'] = first_df[first_key_columns].sum(axis=1)
second_df['ID'] = second_df[second_key_columns].sum(axis=1)

# %%
second_df.head()
# Out:
#                                   Сфера деятельности  Количество вакансий  \
# 0                                       Производство                 1800
# 1           Здравоохранение и социальное обеспечение                 1491
# 2              Продажи, закупки, снабжение, торговля                  734
# 3                                 Образование, наука                  732
# 4  Государственная служба, некоммерческие организ...                  715
#
#                                                   ID
# 0                                       Производство
# 1           Здравоохранение и социальное обеспечение
# 2              Продажи, закупки, снабжение, торговля
# 3                                 Образование, наука
# 4  Государственная служба, некоммерческие организ...

# %%
merge_df = first_df.merge(second_df,how='outer',left_on=['ID'],right_on=['ID'],indicator=True)

# %%
merge_df
# Out:
#                                  Сфера деятельности_x  Количество вакансий_x  \
# 0                                        Производство                 1724.0
# 1   Строительство, ремонт, стройматериалы, недвижи...                 1589.0
# 2            Здравоохранение и социальное обеспечение                 1491.0
# 3               Продажи, закупки, снабжение, торговля                  734.0
# 4                                  Образование, наука                  732.0
# 5   Государственная служба, некоммерческие организ...                  715.0
# 6                           Добывающая промышленность                  466.0
# 7        Транспорт, автобизнес, логистика, склад, ВЭД                  461.0
# 8   Лесная, деревообрабатывающая, целлюлозно-бумаж...                  363.0
# 9                                   ЖКХ, эксплуатация                  320.0
# 10                                  Электроэнергетика                  314.0
# 11                        Безопасность, службы охраны                  300.0
# 12                             Пищевая промышленность                  280.0
# 13                  Работы, не требующие квалификации                  226.0
# 14                                      Юриспруденция                  203.0
# 15                              Рабочие специальности                  173.0
# 16          Административная работа, секретариат, АХО                  150.0
# 17          Сельское хозяйство, экология, ветеринария                  145.0
# 18  Информационные технологии, телекоммуникации, с...                  106.0
# 19                       Туризм, гостиницы, рестораны                  100.0
# 20                                     Машиностроение                   98.0
# 21                      Металлургия, металлообработка                   78.0
# 22                  Искусство, культура и развлечения                   77.0
# 23           Бухгалтерия, налоги, управленческий учет                   68.0
# 24           Услуги населению, сервисное обслуживание                   67.0
# 25    Консалтинг, стратегическое развитие, управление                   57.0
# 26  Банки, кредит, страхование, пенсионное обеспеч...                   47.0
# 27                              Легкая промышленность                   18.0
# 28                             Маркетинг, реклама, PR                   15.0
# 29                                  Домашний персонал                   12.0
# 30             Кадровая служба, управление персоналом                   11.0
# 31                      Спорт, фитнес, салоны красоты                    8.0
# 32                                  Высший менеджмент                    4.0
# 33                                              Итого                11154.0
# 34                                                NaN                    NaN
#
#                                                    ID  \
# 0                                        Производство
# 1   Строительство, ремонт, стройматериалы, недвижи...
# 2            Здравоохранение и социальное обеспечение
# 3               Продажи, закупки, снабжение, торговля
# 4                                  Образование, наука
# 5   Государственная служба, некоммерческие организ...
# 6                           Добывающая промышленность
# 7        Транспорт, автобизнес, логистика, склад, ВЭД
# 8   Лесная, деревообрабатывающая, целлюлозно-бумаж...
# 9                                   ЖКХ, эксплуатация
# 10                                  Электроэнергетика
# 11                        Безопасность, службы охраны
# 12                             Пищевая промышленность
# 13                  Работы, не требующие квалификации
# 14                                      Юриспруденция
# 15                              Рабочие специальности
# 16          Административная работа, секретариат, АХО
# 17          Сельское хозяйство, экология, ветеринария
# 18  Информационные технологии, телекоммуникации, с...
# 19                       Туризм, гостиницы, рестораны
# 20                                     Машиностроение
# 21                      Металлургия, металлообработка
# 22                  Искусство, культура и развлечения
# 23           Бухгалтерия, налоги, управленческий учет
# 24           Услуги населению, сервисное обслуживание
# 25    Консалтинг, стратегическое развитие, управление
# 26  Банки, кредит, страхование, пенсионное обеспеч...
# 27                              Легкая промышленность
# 28                             Маркетинг, реклама, PR
# 29                                  Домашний персонал
# 30             Кадровая служба, управление персоналом
# 31                      Спорт, фитнес, салоны красоты
# 32                                  Высший менеджмент
# 33                                              Итого
# 34  Химическая, нефтехимическая, топливная промышл...
#
#                                  Сфера деятельности_y  Количество вакансий_y  \
# 0                                        Производство                 1800.0
# 1                                                 NaN                    NaN
# 2            Здравоохранение и социальное обеспечение                 1491.0
# 3               Продажи, закупки, снабжение, торговля                  734.0
# 4                                  Образование, наука                  732.0
# 5   Государственная служба, некоммерческие организ...                  715.0
# 6                           Добывающая промышленность                  466.0
# 7        Транспорт, автобизнес, логистика, склад, ВЭД                  461.0
# 8   Лесная, деревообрабатывающая, целлюлозно-бумаж...                  363.0
# 9                                   ЖКХ, эксплуатация                  320.0
# 10                                  Электроэнергетика                  314.0
# 11                        Безопасность, службы охраны                  300.0
# 12                             Пищевая промышленность                  280.0
# 13                  Работы, не требующие квалификации                  226.0
# 14                                      Юриспруденция                  203.0
# 15                              Рабочие специальности                  173.0
# 16          Административная работа, секретариат, АХО                  150.0
# 17          Сельское хозяйство, экология, ветеринария                  145.0
# 18  Информационные технологии, телекоммуникации, с...                  106.0
# 19                       Туризм, гостиницы, рестораны                  100.0
# 20                                     Машиностроение                   98.0
# 21                      Металлургия, металлообработка                   78.0
# 22                  Искусство, культура и развлечения                   77.0
# 23           Бухгалтерия, налоги, управленческий учет                   68.0
# 24           Услуги населению, сервисное обслуживание                   67.0
# 25    Консалтинг, стратегическое развитие, управление                   57.0
# 26  Банки, кредит, страхование, пенсионное обеспеч...                   47.0
# 27                              Легкая промышленность                   18.0
# 28                             Маркетинг, реклама, PR                   15.0
# 29                                  Домашний персонал                   12.0
# 30             Кадровая служба, управление персоналом                   11.0
# 31                      Спорт, фитнес, салоны красоты                    8.0
# 32                                  Высший менеджмент                    4.0
# 33                                              Итого                11154.0
# 34  Химическая, нефтехимическая, топливная промышл...                    2.0
#
#         _merge
# 0         both
# 1    left_only
# 2         both
# 3         both
# 4         both
# 5         both
# 6         both
# 7         both
# 8         both
# 9         both
# 10        both
# 11        both
# 12        both
# 13        both
# 14        both
# 15        both
# 16        both
# 17        both
# 18        both
# 19        both
# 20        both
# 21        both
# 22        both
# 23        both
# 24        both
# 25        both
# 26        both
# 27        both
# 28        both
# 29        both
# 30        both
# 31        both
# 32        both
# 33        both
# 34  right_only

# %%
# удаляем лишние колонки
del_columns = [column for column in merge_df.columns if ('вакансий' not in column) & ('ID' not in column)]

# %%
del_columns
# Out:
# ['Сфера деятельности_x', 'Сфера деятельности_y', '_merge']

# %%
merge_df.drop(columns=del_columns,inplace=True)

# %%
merge_df=merge_df.reindex(columns=['ID','Количество вакансий_x','Количество вакансий_y']) # меняем местами
merge_df.columns = ['Показатель','Первая таблица','Вторая таблица']

# %%
merge_df.fillna(0,inplace=True)

# %%
merge_df[['Первая таблица','Вторая таблица']] = merge_df[['Первая таблица','Вторая таблица']].astype(float,errors='ignore')

# %%
merge_df['Абсолютная разница'] = merge_df['Вторая таблица'] - merge_df['Первая таблица']

# %%
merge_df
# Out:
#                                            Показатель  Первая таблица  \
# 0                                        Производство          1724.0
# 1   Строительство, ремонт, стройматериалы, недвижи...          1589.0
# 2            Здравоохранение и социальное обеспечение          1491.0
# 3               Продажи, закупки, снабжение, торговля           734.0
# 4                                  Образование, наука           732.0
# 5   Государственная служба, некоммерческие организ...           715.0
# 6                           Добывающая промышленность           466.0
# 7        Транспорт, автобизнес, логистика, склад, ВЭД           461.0
# 8   Лесная, деревообрабатывающая, целлюлозно-бумаж...           363.0
# 9                                   ЖКХ, эксплуатация           320.0
# 10                                  Электроэнергетика           314.0
# 11                        Безопасность, службы охраны           300.0
# 12                             Пищевая промышленность           280.0
# 13                  Работы, не требующие квалификации           226.0
# 14                                      Юриспруденция           203.0
# 15                              Рабочие специальности           173.0
# 16          Административная работа, секретариат, АХО           150.0
# 17          Сельское хозяйство, экология, ветеринария           145.0
# 18  Информационные технологии, телекоммуникации, с...           106.0
# 19                       Туризм, гостиницы, рестораны           100.0
# 20                                     Машиностроение            98.0
# 21                      Металлургия, металлообработка            78.0
# 22                  Искусство, культура и развлечения            77.0
# 23           Бухгалтерия, налоги, управленческий учет            68.0
# 24           Услуги населению, сервисное обслуживание            67.0
# 25    Консалтинг, стратегическое развитие, управление            57.0
# 26  Банки, кредит, страхование, пенсионное обеспеч...            47.0
# 27                              Легкая промышленность            18.0
# 28                             Маркетинг, реклама, PR            15.0
# 29                                  Домашний персонал            12.0
# 30             Кадровая служба, управление персоналом            11.0
# 31                      Спорт, фитнес, салоны красоты             8.0
# 32                                  Высший менеджмент             4.0
# 33                                              Итого         11154.0
# 34  Химическая, нефтехимическая, топливная промышл...             0.0
#
#     Вторая таблица  Абсолютная разница
# 0           1800.0                76.0
# 1              0.0             -1589.0
# 2           1491.0                 0.0
# 3            734.0                 0.0
# 4            732.0                 0.0
# 5            715.0                 0.0
# 6            466.0                 0.0
# 7            461.0                 0.0
# 8            363.0                 0.0
# 9            320.0                 0.0
# 10           314.0                 0.0
# 11           300.0                 0.0
# 12           280.0                 0.0
# 13           226.0                 0.0
# 14           203.0                 0.0
# 15           173.0                 0.0
# 16           150.0                 0.0
# 17           145.0                 0.0
# 18           106.0                 0.0
# 19           100.0                 0.0
# 20            98.0                 0.0
# 21            78.0                 0.0
# 22            77.0                 0.0
# 23            68.0                 0.0
# 24            67.0                 0.0
# 25            57.0                 0.0
# 26            47.0                 0.0
# 27            18.0                 0.0
# 28            15.0                 0.0
# 29            12.0                 0.0
# 30            11.0                 0.0
# 31             8.0                 0.0
# 32             4.0                 0.0
# 33         11154.0                 0.0
# 34             2.0                 2.0
